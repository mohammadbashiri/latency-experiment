# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('../Measurements/frame_checking.csv')
data[:5000].plot()

# %%
plt.figure(figsize=(20,5))
plt.plot(data.Chan1.values[3500:4700])
